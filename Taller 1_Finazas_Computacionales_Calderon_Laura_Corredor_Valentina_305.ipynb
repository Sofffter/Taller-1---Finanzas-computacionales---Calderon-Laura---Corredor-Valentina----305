# %% [markdown]
# Taller 1
# Finanzas computacionales
#
#
# Estudiantes:
#
# Laura Sofía Calderón Sterling
#
# Janny Valentina Corredor Mora

# %%
#Importamos las librerias
import pandas as pd
import numpy as np
import scipy as sp
from matplotlib import pyplot as plt
import pandas_datareader.data as pdr
import datetime
import warnings
warnings.filterwarnings("ignore")
# !pip install --quiet yfinance
import yfinance as yf
yf.pdr_override()
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 KB 1.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 KB 4.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 KB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 18.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 KB 9.5 MB/s eta 0:00:00

# %% [markdown]
# Punto 1: Escoja dos acciones de su preferencia en el mercado estadounidense. Para estas dos acciones descargue las series de precios diarios para el periodo Ene-21 a Dic-2022 usando pandas datareader. Con esta información:
#
# a. Calcule los retornos logarítmicos diarios, mensuales y anualizados. Presente los resultados en una tabla.
#
# b. Calcule los retornos esperados y volatilidades anualizadas.
#
# c. Construya una tabla resumen con las estadísticas descriptivas de las series diarias (media, mediana, desv. estándar, curtosis, simetría) de los dos activos.
#
# d. Compare las distribuciones empíricas de los dos activos con la distribución teórica normal.
#
# e. Calcule la matriz de correlaciones de Pearson, rango de Kendall y de Spearman.
#
# f. Implemente las pruebas de normalidad de Kolmogorov-Smirnov para todos los activos.

# %%
#Tickers 
tickers = ['V','F']
# Fechas: desde 01/01/2021 hasta 12/31/2022.
start_date = '2021-01-01'
end_date = '2022-12-31'
acciones = pdr.DataReader(tickers, start="2021-01-01", end="2022-12-31")["Adj Close"]
acciones
# Out:
# [*********************100%***********************]  2 of 2 completed
#                     F           V
# Date
# 2021-01-04   7.722801  214.385727
# 2021-01-05   7.840638  211.186111
# 2021-01-06   8.012859  209.325394
# 2021-01-07   8.212276  210.496964
# 2021-01-08   8.157888  212.111557
# ...               ...         ...
# 2022-12-23  10.686316  205.427643
# 2022-12-27  10.535805  205.886734
# 2022-12-28  10.300631  204.589294
# 2022-12-29  10.855641  207.653290
# 2022-12-30  10.940305  207.353867
#
# [503 rows x 2 columns]

# %%
#Diarios
retornos_diarios = np.log(acciones/acciones.shift()).dropna()
retornos_diarios
# Out:
#                    F         V
# Date
# 2021-01-05  0.015143 -0.015037
# 2021-01-06  0.021728 -0.008850
# 2021-01-07  0.024582  0.005581
# 2021-01-08 -0.006645  0.007641
# 2021-01-11  0.032790 -0.011953
# ...              ...       ...
# 2022-12-23  0.004411  0.003748
# 2022-12-27 -0.014185  0.002232
# 2022-12-28 -0.022574 -0.006322
# 2022-12-29  0.052480  0.014865
# 2022-12-30  0.007769 -0.001443
#
# [502 rows x 2 columns]

# %%
#Mensuales 
retornos_mensuales = retornos_diarios.mean()*21
retornos_mensuales
# Out:
# F    0.014569
# V   -0.001395
# dtype: float64

# %%
#Anualizados
retornos_anualizados = retornos_diarios.mean()*252
retornos_anualizados
# Out:
# F    0.174832
# V   -0.016741
# dtype: float64

# %% [markdown]
# Se evidencia que con la acción de FORD existe mayor retorno.

# %%
#Retornos esperados
retornos_esperados = retornos_diarios.mean() 
retornos_esperados
# Out:
# F    0.000694
# V   -0.000066
# dtype: float64

# %%
#Retornos esperados anualiados
retornos_esperados = retornos_diarios.mean()*252
retornos_esperados
# Out:
# F    0.174832
# V   -0.016741
# dtype: float64

# %%
#Volatilidades anualizadas
sigma = retornos_diarios.std()*np.sqrt(252)
sigma
# Out:
# F    0.457040
# V    0.276901
# dtype: float64

# %% [markdown]
# Con las volatilidades se cumple el supuesto que entre mayor riesgo mayor rentabilidad, ya que la acción FORD presenta más volatilidad y,por ende, mayor retorno.

# %%
#Tabla resumen
media_acciones = acciones.mean()
pd.DataFrame(media_acciones)
# Out:
#             0
# F   13.316699
# V  212.607327

# %%
std_acciones = acciones.std()
pd.DataFrame(std_acciones)
# Out:
#            0
# F   2.752841
# V  13.913532

# %%
mediana_acciones = acciones.median()
pd.DataFrame(mediana_acciones)
# Out:
#             0
# F   12.665152
# V  212.102310

# %%
curtosis_acciones = acciones.kurt()
pd.DataFrame(curtosis_acciones)
# Out:
#           0
# F  1.041467
# V -0.240897

# %%
asimetria_acciones = acciones.skew()
pd.DataFrame(asimetria_acciones)
# Out:
#           0
# F  1.055949
# V -0.064048

# %%
#Tabla resumen estadisticas descriptivas de la serie diaria
tabla_resumen = pd.concat([media_acciones,std_acciones,mediana_acciones,curtosis_acciones,asimetria_acciones], axis = 1)
tabla_resumen.set_axis(['Media', 'Desviacion_Estandar', 'Mediana','Kurtosis','Asimetria'], axis=1)
# Out:
#         Media  Desviacion_Estandar     Mediana  Kurtosis  Asimetria
# F   13.316699             2.752841   12.665152  1.041467   1.055949
# V  212.607327            13.913532  212.102310 -0.240897  -0.064048

# %% [markdown]
# De esta tabla resumen se puede apreciar que la acción FORD tiene una curtosis positiva mientras que la acción VISA tiene una curtosis negativa. Lo cual explica que una curtosis positiva indica una distribución relativamente elevada, mientras que una curtosis negativa indica una distribución relativamente plana.
#
# Asimismo, respecto a la asimetria se evidencia que FORD presente una asimétrica a la derecha porque su indice es positivo; y si es asimétrica a la izquierda, su índices es negativos, el caso de la acción VISA

# %%
#Comparación con immpira-normal 
plt.hist(retornos_diarios['F'], bins=20,density=True, histtype="step");
plt.hist(retornos_diarios['V'], bins=20,density=True, histtype="step");
#RIESGO DE COLA
plt.xlabel("Retornos")
plt.ylabel("Probabilidad");

# %%
#FORD
from scipy.stats import norm
x = np.linspace(-0.1,0.1, num=100) #Secuencia 
plt.hist(retornos_diarios['F'], bins=20,density=True, histtype="step")
plt.plot(x,norm.pdf(x,scale=retornos_diarios['F'].std()),'k')
plt.xlabel("Retornos")
plt.ylabel("Probabilidad")
plt.axvline(retornos_diarios['F'].mean(),color='r');

# %% [markdown]
# Con esto se puede invalidar el supuesto de normalidad. Los datos historicos de la acción FORD no se ajusta a una distribución normal

# %%
#VISA
from scipy.stats import norm
x = np.linspace(-0.1,0.1, num=100) #Secuencia 
plt.hist(retornos_diarios['V'], bins=20,density=True, histtype="step")
plt.plot(x,norm.pdf(x,scale=retornos_diarios['V'].std()),'k')
plt.xlabel("Retornos")
plt.ylabel("Probabilidad")
plt.axvline(retornos_diarios['V'].mean(),color='r'); #se le trazó la media

# %% [markdown]
# Con esto se puede invalidar el supuesto de normalidad. Los datos historicos de la acción VISA no se ajusta a una distribución normal

# %%
#Matriz de correlación de Pearson 
retornos_diarios['F'].corr(retornos_diarios['V'],method="pearson")
# Out:
# 0.36035186003748365

# %%
#Matriz de correlación de Rango de Kendall
retornos_diarios['F'].corr(retornos_diarios['V'], method='kendall')
# Out:
# 0.27199815545803735

# %%
#Matriz de correlación de Spearman
retornos_diarios['F'].corr(retornos_diarios['V'], method='spearman')
# Out:
# 0.3931055402133947

# %% [markdown]
# De acuerdo a los resultados sin importar el tipo de correlación que se haya utilizado (Pearson - Rango de Kendall - Spearman). Se evidencia que su valor es mayor a 0, lo cual indica una correlación positiva. Por ende, se concluye que ambas acciones tienden a incrementarse juntas.

# %% [markdown]
# Punto 2. Escoga 10 acciones y con esa información:
#
# a. Descargar series de precios mensuales de diciembre de 2017 a diciembre de 2022.
#
# b. Calcular retornos y volatilidades anualizadas.
#
# c. Tabular ranking de los retornos esperados

# %%
#Si quisiera hacer el punto 2 con pandas reader. Paso 1. Descargar precios y calcular retornos
tickers_1 = ["BAC","DIS","CPB","CVS","PZZA","XOM","ET","META","BBVA","MCD"]
acciones_1 = pdr.DataReader(tickers_1, start="2017-12-01", end="2022-12-31",interval="1Mo")["Adj Close"]
ret=np.log(acciones_1/acciones_1.shift(1)).dropna()
ret
# Out:
# [*********************100%***********************]  10 of 10 completed
#                  BAC      BBVA       CPB       CVS       DIS        ET  \
# Date
# 2018-01-01  0.080668  0.099579 -0.032963  0.081930  0.018744  0.058509
# 2018-02-01  0.003120 -0.120983 -0.070789 -0.143791 -0.052035 -0.166061
# 2018-03-01 -0.067992 -0.051799  0.006021 -0.085014 -0.026721 -0.069292
# 2018-04-01  0.001409  0.020051 -0.060192  0.115548 -0.001096  0.106064
# 2018-05-01 -0.029853 -0.134400 -0.184352 -0.089137 -0.008609  0.089540
# 2018-06-01 -0.025629  0.017291  0.186574  0.015031  0.052293  0.017163
# 2018-07-01  0.091141  0.041964  0.008841  0.007894  0.080182  0.054159
# 2018-08-01  0.001618 -0.163325 -0.027807  0.156017 -0.005648 -0.039770
# 2018-09-01 -0.048693  0.016000 -0.074167  0.045214  0.042984  0.012218
# 2018-10-01 -0.064025 -0.141271  0.021070 -0.083829 -0.018208 -0.114775
# 2018-11-01  0.032203  0.034145  0.056061  0.109343  0.005731 -0.064452
# 2018-12-01 -0.142018 -0.067606 -0.172472 -0.202168 -0.051890 -0.078622
# 2019-01-01  0.150053  0.120929  0.071354  0.000458  0.024637  0.107553
# 2019-02-01  0.021200  0.034571  0.026958 -0.117714  0.011767  0.005424
# 2019-03-01 -0.047505 -0.075603  0.056927 -0.069821 -0.016170  0.059037
# 2019-04-01  0.102893  0.060933  0.014580  0.008309  0.209961 -0.016399
# 2019-05-01 -0.139435 -0.084915 -0.054585 -0.028117 -0.036657 -0.095707
# 2019-06-01  0.086385  0.023659  0.098534  0.039683  0.055963  0.044501
# 2019-07-01  0.061704 -0.084399  0.031203  0.025010  0.023847  0.021083
# 2019-08-01 -0.109061 -0.073055  0.093322  0.095460 -0.034864 -0.055034
# 2019-09-01  0.058591  0.090514  0.041782  0.034684 -0.051884 -0.017915
# 2019-10-01  0.076088  0.005753 -0.013086  0.051301 -0.003074 -0.038181
# 2019-11-01  0.063499  0.021805  0.013110  0.133076  0.154195 -0.063956
# 2019-12-01  0.055456  0.064778  0.059399 -0.013105 -0.046935  0.106748
# 2022-11-01  0.000477  0.237213  0.136590  0.004772
# 2022-12-01 -0.028919  0.018789 -0.006074 -0.001367

# %%
#Paso 3. Anualizar retornos
ra=returns.mean()*12
ra
# Out:
# BAC     0.043701
# BBVA   -0.025655
# CPB     0.065368
# CVS     0.078314
# DIS    -0.035433
# ET      0.013241
# MCD     0.108852
# META   -0.076555
# PZZA    0.091402
# XOM     0.107897
# dtype: float64

# %%
#Paso 4. Calcular volatilidades anualizadas
sigma=returns.std()*np.sqrt(12)
vol=("Volatilidad anualizada",sigma)
vol
# Out:
# ('Volatilidad anualizada', BAC     0.326401
#  BBVA    0.422536
#  CPB     0.223402
#  CVS     0.268199
#  DIS     0.321140
#  ET      0.556194
#  MCD     0.191522
#  META    0.402351
#  PZZA    0.377754
#  XOM     0.344318
#  dtype: float64)

# %%
#Paso 5. Crear una tabla con los retornos
ranual=pd.DataFrame(ra,index=["BAC","DIS","CPB","CVS","PZZA","XOM","ET","META","BBVA","MCD"])
ranual.columns=["Retornos"]
ranual.sort_values(by="Retornos",ascending=False)
# Out:
#       Retornos
# MCD   0.108852
# XOM   0.107897
# PZZA  0.091402
# CVS   0.078314
# CPB   0.065368
# BAC   0.043701
# ET    0.013241
# BBVA -0.025655
# DIS  -0.035433
# META -0.076555

# %% [markdown]
# De los retornos y las volatilidades se puede concluir que las acciones de la industria alimentaria, a pesar de no ser tan volátiles, generan altos retornos a sus accionistas en comparación con otras industrias. Del mismo modo, se puede afirmar que las acciones del sector petrolero también son rentables, dado que de los activos seleccionados, la compañía ExxonMobil tuvo el segundo mejor promedio de retornos en los últimos 5 años.
#
# En contraste, Meta tuvo el peor promedio de retornos en los últimos 5 años y su riesgo era relativamente alto, la tercera acción más volatil de los activos seleccionados. Esto implica que la acción de Meta no tiene una relación directamente proporcional entre el riesgo asumido y la rentabilidad que obtienen sus accionistas.

# %% [markdown]
# Punto 3. Descargue la serie mensual de precios de Rusell de diciembre de 2011 a diciembre de 2022. Con esta infomacuón calcule al volatilidad mensual y anualizada usando:
#
# a. Desviación estándar
#
# b. Parkinson
#
# c.Garman-Klass
#
# d. Volatilidad ponderada exponencial (EWMA) con lambda de 0.94

# %%
#Si fuera con pandas reader
accionR = pdr.DataReader("^RUT", start="2011-12-01", end="2022-12-31",interval="1Mo")["Adj Close"].dropna()
RetR=np.log(accionR/accionR.shift(1)).dropna()
RetR
# Out:
# [*********************100%***********************]  1 of 1 completed
# Date
# 2012-01-01    0.067704
# 2012-02-01    0.022598
# 2012-03-01    0.023593
# 2012-04-01   -0.016295
# 2012-05-01   -0.069782
#                 ...
# 2022-08-01   -0.022048
# 2022-09-01   -0.102345
# 2022-10-01    0.103830
# 2022-11-01    0.021279
# 2022-12-01   -0.068742
# Name: Adj Close, Length: 132, dtype: float64

# %%
#Paso 1. Descargar la serie mensual de precios de Russell. Si quisiera hacerlo con yfinance
PRusell= yf.download("^RUT", start="2011-12-01", end="2022-12-31",interval="1Mo")["Adj Close"].dropna()
Rr=np.log(PRusell/PRusell.shift(1)).dropna()
#Paso 2. Calcular la volatilidad de Russell con desviación estándar.
#Volatilidad mensual.
SRmensual=Rr.std()
SRmensual
# Out:
# [*********************100%***********************]  1 of 1 completed
# 0.05474479591479422

# %%
#Volatilidad anualizada.
SRanualizada=SRmensual*np.sqrt(12)
SRanualizada
# Out:
# 0.18964153594882538

# %%
Rrroll=Rr.rolling(window=12).std()
Rrroll.plot(xlabel="Año", ylabel="Desviación estándar",title="Volatilidad de los retornos");

# %%
#Paso 3. Calcular la volatilidad de Russell con Parkinson. 
#No se filtra por precio ajustado porque trabaja con los precios de cierre y apertura
Pr=yf.download("^RUT", start="2011-12-31", end="2022-12-31",interval="1Mo").dropna()
lnR=np.log(Pr["High"]/Pr["Low"]).dropna()
SRP=((1/(4*np.log(2)))*lnR**2)**0.5
SRP
# Out:
# [*********************100%***********************]  1 of 1 completed
# Date
# 2012-01-01    0.049605
# 2012-02-01    0.026554
# 2012-03-01    0.045991
# 2012-04-01    0.042529
# 2012-05-01    0.064386
#                 ...
# 2022-08-01    0.058028
# 2022-09-01    0.086390
# 2022-10-01    0.073133
# 2022-11-01    0.048681
# 2022-12-01    0.058579
# Length: 132, dtype: float64

# %%
SRP.plot(xlabel="Año",ylabel="Volatilidad",title="Volatilidad de los retornos según Parkinson",c="g");

# %%
#Volatilidad anualizada de Parkinson
SRP.mean()*np.sqrt(12)
# Out:
# 0.17702537362965717

# %%
#Paso 4. Calcular la volatilidad de Russell con Garman- Klass
lnCOR=np.log(Pr["Close"]/Pr["Open"]).dropna()
SGKR=(0.5*lnR**2-(2*np.log(2)-1)*lnCOR**2)**0.5
SGKR
# Out:
# Date
# 2012-01-01    0.047539
# 2012-02-01    0.029346
# 2012-03-01    0.052724
# 2012-04-01    0.049245
# 2012-05-01    0.061736
#                 ...
# 2022-08-01    0.067750
# 2022-09-01    0.083748
# 2022-10-01    0.065267
# 2022-11-01    0.056867
# 2022-12-01    0.052694
# Length: 132, dtype: float64

# %%
SGKR.plot(xlabel="Año",ylabel="Volatilidad",title="Volatilidad de retornos según Garman - Klass",c="r");

# %%
#Volatilidades anualizadas
SGKR.mean()*np.sqrt(12)
# Out:
# 0.18169091631978984

# %%
#Paso 5. Calcular la volatilidad de Russell con EWMA, asumiendo un lambda de 0.94

# %%
def ewma_vol(retornos,Lambda):
  Lambda=0.94
  k= len(retornos)
  td= np.arange(k-1,-1,-1)
  alpha=Lambda**td
  var_s=alpha*retornos**2
  var_s=var_s.sum()
  var_s=var_s*(1-Lambda)
  vol_ewma=np.sqrt(var_s)
  return(vol_ewma)

# %%
pr=yf.download("^RUT", start="2011-12-31", end="2022-12-31",interval="1Mo")["Adj Close"]
rr=np.log(pr/pr.shift(1)).dropna()
ewma_vol(rr,Lambda=0.94)
# Out:
# [*********************100%***********************]  1 of 1 completed
# 0.06830708248540157

# %%
#Volatilidades anualizadas
ewma_vol(rr,Lambda=0.94)*np.sqrt(12)
# Out:
# 0.2366226747630274

# %% [markdown]
# En los gráficos de volatilidad del tercer punto se puede evidenciar que el índice Russell 2000 fue bastante volátil a inicios de 2020, en contraste, su menor volatilidad desde 2012 se dio en el tercer trimestre de 2017.
#
# Adicionalmente, se puede deducir que la volatilidad anualizada del índice tiende a 0.18, dado que los métodos más completos para calcular la volatilidad (Garman - Klass y Parkinson) se acercan bastante a este valor, incluso al calcular el riesgo con la desviación estándar se obtiene un resultado muy similar.
